# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("TESLA STOCK DATA_18_01_21.csv",index_col=0)

# %%
data
# Out:
#        timestamp       Close        Open         Low        High     Volume
# 0     2019-01-23   58.829998   58.879997   58.626000   58.921997        0.0
# 1     2019-01-23   59.144000   58.809998   58.803997   59.158000        0.0
# 2     2019-01-23   58.900000   59.109997   58.900000   59.150000        0.0
# 3     2019-01-23   58.990000   58.844000   58.840004   59.040000        0.0
# 4     2019-01-23   58.720000   59.000000   58.635998   59.092000        0.0
# ...          ...         ...         ...         ...         ...        ...
# 8084  2021-01-22  844.539978  839.350098  839.000000  844.700012  1850572.0
# 8085  2021-01-22  846.500000  844.700012  843.239990  848.000000  2010108.0
# 8086  2021-01-22  846.440000  846.640000  838.663900  847.740000   514017.0
# 8087  2021-01-22  846.400000  846.420000  846.060000  847.190000        0.0
# 8088  2021-01-23  846.300000  846.300000  846.000000  846.490000        0.0
#
# [8089 rows x 6 columns]

# %%
data['timestamp']=pd.to_datetime(data['timestamp'])

# %%
df_new=data.rename(columns={'timestamp':'Date'})
df_new
# Out:
#            Date       Close        Open         Low        High     Volume
# 0    2019-01-23   58.829998   58.879997   58.626000   58.921997        0.0
# 1    2019-01-23   59.144000   58.809998   58.803997   59.158000        0.0
# 2    2019-01-23   58.900000   59.109997   58.900000   59.150000        0.0
# 3    2019-01-23   58.990000   58.844000   58.840004   59.040000        0.0
# 4    2019-01-23   58.720000   59.000000   58.635998   59.092000        0.0
# ...         ...         ...         ...         ...         ...        ...
# 8084 2021-01-22  844.539978  839.350098  839.000000  844.700012  1850572.0
# 8085 2021-01-22  846.500000  844.700012  843.239990  848.000000  2010108.0
# 8086 2021-01-22  846.440000  846.640000  838.663900  847.740000   514017.0
# 8087 2021-01-22  846.400000  846.420000  846.060000  847.190000        0.0
# 8088 2021-01-23  846.300000  846.300000  846.000000  846.490000        0.0
#
# [8089 rows x 6 columns]

# %%
#df_new.sample()
# Out:
#            Date      Close     Open        Low  High    Volume
# 1841 2019-07-18  50.960197  50.8862  50.849998  51.0  436611.0

# %%
df_new.describe(include= 'all')
# Out:
# <ipython-input-8-ebe486fdd406>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_new.describe(include= 'all')
#                        Date        Close         Open          Low  \
# count                  8089  8083.000000  8083.000000  8083.000000
# unique                  606          NaN          NaN          NaN
# top     2020-08-26 00:00:00          NaN          NaN          NaN
# freq                     17          NaN          NaN          NaN
# first   2019-01-23 00:00:00          NaN          NaN          NaN
# last    2021-01-23 00:00:00          NaN          NaN          NaN
# mean                    NaN   196.393555   196.325947   194.816137
# std                     NaN   196.933714   196.827821   195.243636
# min                     NaN    35.576000    35.573997    35.398380
# 25%                     NaN    53.307999    53.324499    53.089999
# 50%                     NaN   102.800003   102.710000   101.960000
# 75%                     NaN   299.800000   299.800000   297.925000
# max                     NaN   882.450012   882.489990   875.120000
#
#                 High        Volume
# count   8.083000e+03  8.083000e+03
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean    5.592472e+05  1.207394e+06
# std     5.026162e+07  2.743453e+06
# min     3.579400e+01  0.000000e+00
# 25%     5.360400e+01  0.000000e+00
# 50%     1.036000e+02  0.000000e+00
# 75%     3.016500e+02  1.319866e+06
# max     4.518796e+09  4.321218e+07

# %%
df_new.value_counts()
# Out:
# Date        Close       Open        Low         High        Volume
# 2019-11-01  63.000000   63.000000   63.000000   63.000000   0.0          2
# 2019-10-03  46.040000   46.510002   46.002000   46.510002   0.0          1
# 2019-10-01  48.388000   48.390000   48.388000   48.390000   0.0          1
#             48.390000   48.400000   48.364002   48.440000   0.0          1
#             48.402000   48.404000   48.400000   48.404000   0.0          1
#                                                                         ..
# 2020-06-01  179.574997  178.959991  178.399994  179.800003  1736564.0    1
#             179.599980  179.097990  179.097990  179.910000  0.0          1
#             179.600000  179.440000  179.000000  180.498000  0.0          1
# 2020-06-02  176.279999  176.557327  176.199997  177.430008  932875.0     1
# 2019-01-23  57.099998   58.250999   56.517998   58.450001   2089444.0    1
# Length: 8082, dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8089 entries, 0 to 8088
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8089 non-null   datetime64[ns]
#  1   Close   8083 non-null   float64
#  2   Open    8083 non-null   float64
#  3   Low     8083 non-null   float64
#  4   High    8083 non-null   float64
#  5   Volume  8083 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 442.4 KB

# %%
df_new.isnull().sum()
# Out:
# Date      0
# Close     6
# Open      6
# Low       6
# High      6
# Volume    6
# dtype: int64

# %%
#print (df_new['Close'].isnull())

# %%
#df_new['Close'].median()
df_new['Close'].fillna(102.800003,inplace=True)

# %%
#print (df_new['Open'].isnull())

# %%
df_new['Open'].fillna(102.710000,inplace=True)

# %%
df_new['Low'].fillna(101.960000,inplace=True)

# %%
df_new['High'].fillna(1.036000e+02,inplace=True)

# %%
df_new['Volume'].fillna(0.000000e+00,inplace=True)

# %%
df_new.isnull().sum()
# Out:
# Date      0
# Close     0
# Open      0
# Low       0
# High      0
# Volume    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(20,8))
plt.plot('Date','Close',data=df_new)
plt.xlabel('Date')
plt.ylabel('Close Price')
#plt.xticks(rotation=45)
# Out:
# Text(0, 0.5, 'Close Price')

# %%
title='TESLA STOCK PRICE'
ylabel='Price'
ax=df_new[['Open','Close']].plot(figsize=(20,8),title=title)
ax.autoscale(axis='x',tight='True')
ax.set(ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'Price')]

# %%
#creating a daily lag column(shifting the close price by one day back) to create the column for daily returns
df_new['Daily Lag']= df_new['Close'].shift(1)
df_new.head()
# Out:
#         Date      Close       Open        Low       High  Volume  Daily Lag
# 0 2019-01-23  58.829998  58.879997  58.626000  58.921997     0.0        NaN
# 1 2019-01-23  59.144000  58.809998  58.803997  59.158000     0.0  58.829998
# 2 2019-01-23  58.900000  59.109997  58.900000  59.150000     0.0  59.144000
# 3 2019-01-23  58.990000  58.844000  58.840004  59.040000     0.0  58.900000
# 4 2019-01-23  58.720000  59.000000  58.635998  59.092000     0.0  58.990000

# %%
#creating a column for daily returns which tells us the return gathered in a day after the stock price closes
df_new['Daily Returns']=(df_new['Daily Lag']/df_new['Close'])-1
df_new.head()
# Out:
#         Date      Close       Open        Low       High  Volume  Daily Lag  \
# 0 2019-01-23  58.829998  58.879997  58.626000  58.921997     0.0        NaN
# 1 2019-01-23  59.144000  58.809998  58.803997  59.158000     0.0  58.829998
# 2 2019-01-23  58.900000  59.109997  58.900000  59.150000     0.0  59.144000
# 3 2019-01-23  58.990000  58.844000  58.840004  59.040000     0.0  58.900000
# 4 2019-01-23  58.720000  59.000000  58.635998  59.092000     0.0  58.990000
#
#    Daily Returns
# 0            NaN
# 1      -0.005309
# 2       0.004143
# 3      -0.001526
# 4       0.004598

# %%
#creating a new column that calculates gap btw close price and the day after open price
df_new['Delta']=((df_new['Open']-df_new['Daily Lag'])/df_new['Daily Lag'])*100
df_new.head()
# Out:
#         Date      Close       Open        Low       High  Volume  Daily Lag  \
# 0 2019-01-23  58.829998  58.879997  58.626000  58.921997     0.0        NaN
# 1 2019-01-23  59.144000  58.809998  58.803997  59.158000     0.0  58.829998
# 2 2019-01-23  58.900000  59.109997  58.900000  59.150000     0.0  59.144000
# 3 2019-01-23  58.990000  58.844000  58.840004  59.040000     0.0  58.900000
# 4 2019-01-23  58.720000  59.000000  58.635998  59.092000     0.0  58.990000
#
#    Daily Returns     Delta    Weekday  delta_high_low
# 0            NaN       NaN  Wednesday        0.504890
# 1      -0.005309 -0.033996  Wednesday        0.602005
# 2       0.004143 -0.057492  Wednesday        0.424448
# 3      -0.001526 -0.095076  Wednesday        0.339898
# 4       0.004598  0.016952  Wednesday        0.777683

# %%
df_new['Weekday']=df_new['Date'].dt.day_name()
df_new
# Out:
#            Date       Close        Open         Low        High     Volume  \
# 0    2019-01-23   58.829998   58.879997   58.626000   58.921997        0.0
# 1    2019-01-23   59.144000   58.809998   58.803997   59.158000        0.0
# 2    2019-01-23   58.900000   59.109997   58.900000   59.150000        0.0
# 3    2019-01-23   58.990000   58.844000   58.840004   59.040000        0.0
# 4    2019-01-23   58.720000   59.000000   58.635998   59.092000        0.0
# ...         ...         ...         ...         ...         ...        ...
# 8084 2021-01-22  844.539978  839.350098  839.000000  844.700012  1850572.0
# 8085 2021-01-22  846.500000  844.700012  843.239990  848.000000  2010108.0
# 8086 2021-01-22  846.440000  846.640000  838.663900  847.740000   514017.0
# 8087 2021-01-22  846.400000  846.420000  846.060000  847.190000        0.0
# 8088 2021-01-23  846.300000  846.300000  846.000000  846.490000        0.0
#
#        Daily Lag  Daily Returns     Delta    Weekday  delta_high_low
# 0            NaN            NaN       NaN  Wednesday        0.504890
# 1      58.829998      -0.005309 -0.033996  Wednesday        0.602005
# 2      59.144000       0.004143 -0.057492  Wednesday        0.424448
# 3      58.900000      -0.001526 -0.095076  Wednesday        0.339898
# 4      58.990000       0.004598  0.016952  Wednesday        0.777683
# ...          ...            ...       ...        ...             ...
# 8084  839.299988      -0.006205  0.005970     Friday        0.679382
# 8085  844.539978      -0.002315  0.018949     Friday        0.564491
# 8086  846.500000       0.000071  0.016539     Friday        1.082209
# 8087  846.440000       0.000047 -0.002363     Friday        0.133560
# 8088  846.400000       0.000118 -0.011815   Saturday        0.057920
#
# [8089 rows x 11 columns]

# %%
order=['Monday','Tuesday','Wednesday','Thursday','Friday']
sns.boxplot(x=df_new['Weekday'],y=df_new['Delta'],order=order)
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='Delta'>

# %% [markdown]
# the highest gap is likely to occur on ----Monday. selling stocks at the opening time of the the day with the highest gap is more profitable

# %%
#calculating the amplitude in the daily stock price between high price and low price in %
df_new['delta_high_low']=((df_new['High']-df_new['Low'])/df_new['Low'])*100
df_new
# Out:
#            Date       Close        Open         Low        High     Volume  \
# 0    2019-01-23   58.829998   58.879997   58.626000   58.921997        0.0
# 1    2019-01-23   59.144000   58.809998   58.803997   59.158000        0.0
# 2    2019-01-23   58.900000   59.109997   58.900000   59.150000        0.0
# 3    2019-01-23   58.990000   58.844000   58.840004   59.040000        0.0
# 4    2019-01-23   58.720000   59.000000   58.635998   59.092000        0.0
# ...         ...         ...         ...         ...         ...        ...
# 8084 2021-01-22  844.539978  839.350098  839.000000  844.700012  1850572.0
# 8085 2021-01-22  846.500000  844.700012  843.239990  848.000000  2010108.0
# 8086 2021-01-22  846.440000  846.640000  838.663900  847.740000   514017.0
# 8087 2021-01-22  846.400000  846.420000  846.060000  847.190000        0.0
# 8088 2021-01-23  846.300000  846.300000  846.000000  846.490000        0.0
#
#        Daily Lag  Daily Returns     Delta    Weekday  delta_high_low
# 0            NaN            NaN       NaN  Wednesday        0.504890
# 1      58.829998      -0.005309 -0.033996  Wednesday        0.602005
# 2      59.144000       0.004143 -0.057492  Wednesday        0.424448
# 3      58.900000      -0.001526 -0.095076  Wednesday        0.339898
# 4      58.990000       0.004598  0.016952  Wednesday        0.777683
# ...          ...            ...       ...        ...             ...
# 8084  839.299988      -0.006205  0.005970     Friday        0.679382
# 8085  844.539978      -0.002315  0.018949     Friday        0.564491
# 8086  846.500000       0.000071  0.016539     Friday        1.082209
# 8087  846.440000       0.000047 -0.002363     Friday        0.133560
# 8088  846.400000       0.000118 -0.011815   Saturday        0.057920
#
# [8089 rows x 11 columns]

# %%
#plot for Amplitude
order=['Monday','Tuesday','Wednesday','Thursday','Friday']
#sns.set(rc={'figure.figsize':(11,8)},font_scale=1.5,style="whitegrid")
sns.reset_orig
sns.boxplot(x=df_new['Weekday'],y=df_new['delta_high_low'],order=order)
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='delta_high_low'>

# %% [markdown]
# the above visualisation is to show which day is better for trading based on the price amplitude .

# %%
df_new['Daily Returns'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
#calculating average daily returns
mean=df_new['Daily Returns'].mean()
std=df_new['Daily Returns'].std()
print('mean =',mean)
print('standard deviation =',std)
# Out:
# mean = 0.0009369510857844748
# standard deviation = 0.08425585865692974

# %% [markdown]
# having a low standard deviation indicates that investing in this stock(Tesla) is less risky i.e chances of having a

# %%
df_new['Daily Returns'].hist(bins=20)
plt.axvline(mean,color='red',linestyle='dashed',linewidth=2)
plt.axvline(std,color='green',linestyle='dashed',linewidth=2)
plt.axvline(-std,color='green',linestyle='dashed',linewidth=2)

# %% [markdown]
# the above histogram shows a normal distribution with mean 0

# %%
df_new['Daily Returns'].kurtosis()
# Out:
# 3379.252453881898

# %% [markdown]
# since we have a postive kurtosis, it shows that the chances of having outliers(extreme values) are rare.

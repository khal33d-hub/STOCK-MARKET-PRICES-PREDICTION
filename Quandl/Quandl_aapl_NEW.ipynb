# %%
import requests
import pandas as pd
import json
from datetime import datetime

# %%
url = "https://www.quandl.com/api/v3/datasets/EOD/AAPL/data.json?api_key=Srm1pBoFk1B8Eh-JPYt9"

querystring = {"symbol":"AAPL","region":"US"}

headers = {
    'quandl_api-key': "Srm1pBoFk1B8Eh-JPYt9",
    'quandl-host': "https://www.quandl.com/api"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %% [raw]
# curl "https://www.quandl.com/api/v3/datasets/FRED/GDP.csv?collapse=annual&rows=6&order=asc&column_index=1&api_key=YOURAPIKEY"

# %%
url_2 = "https://www.quandl.com/api/v3/datasets/EOD/AAPL/data.json?start_date=2015-01-01&end_date=2021-01-01&api_key=Srm1pBoFk1B8Eh-JPYt9"

response_2 = requests.request("GET", url_2)

# %%
response_2.json()
# Out:
# {'dataset_data': {'limit': None,
#   'transform': None,
#   'column_index': None,
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Volume',
#    'Dividend',
#    'Split',
#    'Adj_Open',
#    'Adj_High',
#    'Adj_Low',
#    'Adj_Close',
#    'Adj_Volume'],
#   'start_date': '2015-01-01',
#   'end_date': '2017-12-28',
#   'frequency': 'daily',
#   'data': [['2017-12-28',
#     171.0,
#     171.85,
#     170.48,
#     171.08,
#     16480187.0,
#     0.0,
#     1.0,
#     41.13697186411518,
#     41.34145388800113,
#     41.01187697891436,
#     41.15621723106916,
#     65920748.0],
#    ['2017-12-27',
#     170.1,
#     170.78,
#     169.71,
#     170.6,
#     21498213.0,
#     0.0,
#     1.0,
#     40.920461485882996,
#     41.084047104991754,
#     40.82664032198238,
#     41.04074502934532,
#     85992852.0],
#    ['2017-12-26',
#     170.8,
#     171.47,
#     169.679,
#     170.57,
#     33185536.0,
#     0.0,
#     1.0,
# ...

# %%
url_3 = "https://www.quandl.com/api/v3/datasets/WIKI/FB/data.json?download_type=full&api_key=Srm1pBoFk1B8Eh-JPYt9"

# querystring_3 = {"start_date":"2019-01-01", "end_date":"2021-01-01"}
querystring_3 = {"start_date":"2015-01-01", "end_date":"2021-01-01"}


# headers_3 = {
#     'quandl_api-key': "1EK13m8dNx1sUxMKCWtK",
#     'quandl-host': "https://www.quandl.com/api"
#     }


response_3 = requests.request("GET", url_3, params=querystring_3)
# response_3 = requests.get(url_3, params={"start_date":"2019-01-1", "end_date":"2021-01-20"})
# response_3 = requests.get(url_3, params=querystring)

# %%
data_3 = response_3.json()

# %%
data_3['dataset_data']['data'][4][0]
# Out:
# '2018-03-21'

# %%
data_3
# Out:
# {'dataset_data': {'limit': None,
#   'transform': None,
#   'column_index': None,
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Volume',
#    'Ex-Dividend',
#    'Split Ratio',
#    'Adj. Open',
#    'Adj. High',
#    'Adj. Low',
#    'Adj. Close',
#    'Adj. Volume'],
#   'start_date': '2015-01-01',
#   'end_date': '2018-03-27',
#   'frequency': 'daily',
#   'data': [['2018-03-27',
#     156.31,
#     162.85,
#     150.75,
#     152.19,
#     76787884.0,
#     0.0,
#     1.0,
#     156.31,
#     162.85,
#     150.75,
#     152.19,
#     76787884.0],
#    ['2018-03-26',
#     160.82,
#     161.1,
#     149.02,
#     160.06,
#     125438294.0,
#     0.0,
#     1.0,
#     160.82,
#     161.1,
#     149.02,
#     160.06,
#     125438294.0],
#    ['2018-03-23',
#     165.44,
#     167.1,
#     159.02,
#     159.39,
#     52306891.0,
#     0.0,
#     1.0,
#     165.44,
#     167.1,
#     159.02,
#     159.39,
#     52306891.0],
#    ['2018-03-22',
# ...

# %%
data
# Out:
# {'dataset_data': {'limit': None,
#   'transform': None,
#   'column_index': None,
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Volume',
#    'Dividend',
#    'Split',
#    'Adj_Open',
#    'Adj_High',
#    'Adj_Low',
#    'Adj_Close',
#    'Adj_Volume'],
#   'start_date': '2013-09-01',
#   'end_date': '2017-12-28',
#   'frequency': 'daily',
#   'data': [['2017-12-28',
#     171.0,
#     171.85,
#     170.48,
#     171.08,
#     16480187.0,
#     0.0,
#     1.0,
#     41.13697186411518,
#     41.34145388800113,
#     41.01187697891436,
#     41.15621723106916,
#     65920748.0],
#    ['2017-12-27',
#     170.1,
#     170.78,
#     169.71,
#     170.6,
#     21498213.0,
#     0.0,
#     1.0,
#     40.920461485882996,
#     41.084047104991754,
#     40.82664032198238,
#     41.04074502934532,
#     85992852.0],
#    ['2017-12-26',
#     170.8,
#     171.47,
#     169.679,
#     170.57,
#     33185536.0,
#     0.0,
#     1.0,
# ...

# %%
# Out:
# {'quandl_error': {'code': 'QEAx01',
#   'message': 'We could not recognize your API key: 1EK13m8dNx1sUxMKCWtK?start_date=2019-1-1, end_date=2021-1-20. Please check your API key and try again. You can find your API key under your account settings.'}}

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
def print_json(response):
    word = json.dumps(response, sort_keys=True, indent=4)
    
    print(word)

    
print_json(response.json())
# Out:
# {
#     "dataset_data": {
#         "collapse": null,
#         "column_index": null,
#         "column_names": [
#             "Date",
#             "Open",
#             "High",
#             "Low",
#             "Close",
#             "Volume",
#             "Dividend",
#             "Split",
#             "Adj_Open",
#             "Adj_High",
#             "Adj_Low",
#             "Adj_Close",
#             "Adj_Volume"
#         ],
#         "data": [
#             [
#                 "2017-12-28",
#                 171.0,
#                 171.85,
#                 170.48,
#                 171.08,
#                 16480187.0,
#                 0.0,
#                 1.0,
#                 41.13697186411518,
#                 41.34145388800113,
#                 41.01187697891436,
#                 41.15621723106916,
#                 65920748.0
#             ],
#             [
#                 "2017-12-27",
#                 170.1,
#                 170.78,
# ...

# %%
data=response.json()

# %%
columns
# Out:
# ['Date',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Dividend',
#  'Split',
#  'Adj_Open',
#  'Adj_High',
#  'Adj_Low',
#  'Adj_Close',
#  'Adj_Volume']

# %%
columns = data['dataset_data']['column_names']

# %%
date=[]
index=0

for x in range(5000):
    
    try:
        date.append(data_3['dataset_data']['data'][index][0])
        index += 1
    
    except IndexError:
        break

# %%
Open=[]
index=0

for x in range(2000):
    
    try:
        Open.append(data['dataset_data']['data'][index][1])
        index += 1
    
    except IndexError:
        break

# %%
high=[]
index=0

for x in range(2000):
    
    try:
        high.append(data['dataset_data']['data'][index][2])
        index += 1
    
    except IndexError:
        break

# %%
low=[]
index=0

for x in range(2000):
    
    try:
        low.append(data['dataset_data']['data'][index][3])
        index += 1
    
    except IndexError:
        break

# %%
close=[]
index=0

for x in range(2000):
    
    try:
        close.append(data['dataset_data']['data'][index][4])
        index += 1
    
    except IndexError:
        break

# %%
close = []
index=0

for x in range(1090):
    close.append(data['dataset_data']['data'][index][4])
    index += 1

# %%
volume=[]
index=0

for x in range(2000):
    
    try:
        volume.append(data['dataset_data']['data'][index][5])
        index += 1
    
    except IndexError:
        break

# %%
div=[]
index=0

for x in range(2000):
    
    try:
        div.append(data['dataset_data']['data'][index][6])
        index += 1
    
    except IndexError:
        break

# %%
split=[]
index=0

for x in range(2000):
    
    try:
        split.append(data['dataset_data']['data'][index][7])
        index += 1
    
    except IndexError:
        break

# %%
Adjopen=[]
index=0

for x in range(2000):
    
    try:
        Adjopen.append(data['dataset_data']['data'][index][8])
        index += 1
    
    except IndexError:
        break

# %%
Adjhigh=[]
index=0

for x in range(2000):
    
    try:
        Adjhigh.append(data['dataset_data']['data'][index][9])
        index += 1
    
    except IndexError:
        break

# %%
Adjlow=[]
index=0

for x in range(2000):
    
    try:
        Adjlow.append(data['dataset_data']['data'][index][10])
        index += 1
    
    except IndexError:
        break

# %%
Adjclose=[]
index=0

for x in range(2000):
    
    try:
        Adjclose.append(data['dataset_data']['data'][index][11])
        index += 1
    
    except IndexError:
        break

# %%
Adjvol=[]
index=0

for x in range(2000):
    
    try:
        Adjvol.append(data['dataset_data']['data'][index][12])
        index += 1
    
    except IndexError:
        break

# %%
dict_of_lists = {"Date":date,
            "Open":Open,
            "High":high,
            "Low":low,
            "Close":close,
            "Volume":volume,
            "Dividend":div,
            "Split":split,
            "Adj_Open":Adjopen,
            "Adj_High":Adjhigh,
            "Adj_Low":Adjlow,
            "Adj_Close":Adjclose,
            "Adj_Volume":Adjvol
                }

# %%
AAPL_df = pd.DataFrame(dict_of_lists)

# %%
AAPL_df.head()
# Out:
#          Date    Open     High      Low   Close      Volume  Dividend  Split  \
# 0  2017-12-28  171.00  171.850  170.480  171.08  16480187.0       0.0    1.0
# 1  2017-12-27  170.10  170.780  169.710  170.60  21498213.0       0.0    1.0
# 2  2017-12-26  170.80  171.470  169.679  170.57  33185536.0       0.0    1.0
# 3  2017-12-22  174.68  175.424  174.500  175.01  16349444.0       0.0    1.0
# 4  2017-12-21  174.17  176.020  174.100  175.01  20949896.0       0.0    1.0
#
#     Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume
# 0  41.136972  41.341454  41.011877  41.156217   65920748.0
# 1  40.920461  41.084047  40.826640  41.040745   85992852.0
# 2  41.088858  41.250038  40.819183  41.033528  132742144.0
# 3  42.022259  42.201241  41.978957  42.101646   65397776.0
# 4  41.899570  42.344619  41.882730  42.101646   83799584.0

# %%
AAPL_df.to_excel('AAPL.xlsx')

# %%
import matplotlib as plt

# %%
AAPL_df.plot(x='Date', y='Close',kind='line', figsize=(15,8))

# %%
AAPL_df.head()
# Out:
#          Date    Open     High      Low   Close      Volume  Dividend  Split  \
# 0  2017-12-28  171.00  171.850  170.480  171.08  16480187.0       0.0    1.0
# 1  2017-12-27  170.10  170.780  169.710  170.60  21498213.0       0.0    1.0
# 2  2017-12-26  170.80  171.470  169.679  170.57  33185536.0       0.0    1.0
# 3  2017-12-22  174.68  175.424  174.500  175.01  16349444.0       0.0    1.0
# 4  2017-12-21  174.17  176.020  174.100  175.01  20949896.0       0.0    1.0
#
#     Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume
# 0  41.136972  41.341454  41.011877  41.156217   65920748.0
# 1  40.920461  41.084047  40.826640  41.040745   85992852.0
# 2  41.088858  41.250038  40.819183  41.033528  132742144.0
# 3  42.022259  42.201241  41.978957  42.101646   65397776.0
# 4  41.899570  42.344619  41.882730  42.101646   83799584.0

# %% [markdown]
# plt.title('Historical Stock_price of the AAPL in US', size=15)
# plt.xlabel('Volume', size=12)
# plt.ylabel('close Prices', size=12)
# plt.grid()
